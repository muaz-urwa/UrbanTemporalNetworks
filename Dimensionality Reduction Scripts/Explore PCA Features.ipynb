# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/home/urwa/Documents/Projects/NYU Remote/project/PCA_features.csv')

# %%
data.head()
# Out:
#          Date  Hour         1         2         3         4         5  \
# 0  2017-01-01     0 -0.010811 -0.003923 -0.001665 -0.000793 -0.001489
# 1  2017-01-01     1 -0.010811 -0.003923 -0.001665 -0.000793 -0.001489
# 2  2017-01-01     2 -0.010811 -0.003923 -0.001665 -0.000793 -0.001489
# 3  2017-01-01     3 -0.010811 -0.003923 -0.001665 -0.000793 -0.001489
# 4  2017-01-01     4 -0.010811 -0.003923 -0.001665 -0.000793 -0.001489
#
#           6         7         8         9        10
# 0 -0.001091 -0.001051 -0.000025 -0.001281 -0.000891
# 1 -0.001091 -0.001051 -0.000025 -0.001281 -0.000891
# 2 -0.001091 -0.001051 -0.000025 -0.001281 -0.000891
# 3 -0.001091 -0.001051 -0.000025 -0.001281 -0.000891
# 4 -0.001091 -0.001051 -0.000025 -0.001281 -0.000891

# %%
data.plot(y='1', figsize=(15,5))

# %%
data.plot(y='1', figsize=(5,5), kind='hist')

# %%
for c in data.columns:
    print(c)
    print(len(set(data[c])))
# Out:
# Date
# 730
# Hour
# 24
# 1
# 173
# 2
# 267
# 3
# 269
# 4
# 269
# 5
# 269
# 6
# 269
# 7
# 269
# 8
# 269
# 9
# 269
# 10
# 269

# %%
data.corr()
# Out:
#           Hour             1             2             3             4  \
# Hour  1.000000  2.036147e-02  1.762469e-02  3.652144e-02  2.351678e-02
# 1     0.020361  1.000000e+00 -2.881375e-16 -2.302816e-15  5.561434e-16
# 2     0.017625 -2.881375e-16  1.000000e+00  2.215512e-11 -9.183958e-12
# 3     0.036521 -2.302816e-15  2.215512e-11  1.000000e+00 -4.612290e-09
# 4     0.023517  5.561434e-16 -9.183958e-12 -4.612290e-09  1.000000e+00
# 5    -0.008018  3.401329e-15 -4.221861e-11 -2.047546e-08  8.712095e-09
# 6     0.026234 -2.728958e-15  9.833725e-11  4.818687e-08 -2.068918e-08
# 7     0.025234  2.002864e-14 -1.361637e-10 -6.847675e-08  2.802202e-08
# 8    -0.007172 -5.730570e-14  4.245060e-10  2.093609e-07 -8.817221e-08
# 9     0.028194  1.207419e-13 -1.337805e-09 -6.521887e-07  2.739174e-07
# 10    0.008189  9.734082e-15 -2.551710e-10 -1.175004e-07  5.972552e-08
#
#                  5             6             7             8             9  \
# ...

# %%
rawData = pd.read_csv('JfkVehiceByHour.csv')

# %%
rawData.head()
# Out:
#          Date  Hour  DOLocationID  vehicle_count
# 0  2017-01-01     0             1            0.0
# 1  2017-01-01     0             2            0.0
# 2  2017-01-01     0             3            0.0
# 3  2017-01-01     0             4            1.0
# 4  2017-01-01     0             5            0.0

# %%
x = 1
for loc in set(rawData.DOLocationID):
    df = rawData[rawData.DOLocationID == loc]
    n = len(set(df.vehicle_count))
    print( n)
    x = n*x
# Out:
# 13
# 3
# 6
# 16
# 3
# 4
# 27
# 3
# 16
# 32
# 8
# 3
# 25
# 16
# 8
# 12
# 27
# 7
# 7
# 14
# 8
# 10
# 5
# 12
# 26
# 18
# 4
# 15
# 9
# 4
# 4
# 5
# 22
# 5
# 11
# 26
# 32
# 16
# 17
# 17
# 18
# 16
# 16
# 3
# 9
# 4
# 5
# 50
# 27
# 22
# 6
# 12
# 7
# 8
# 7
# 9
# 4
# 2
# 4
# 35
# 19
# 10
# 9
# 22
# 13
# 7
# 37
# 7
# 22
# 12
# 13
# 7
# 14
# 19
# 19
# 9
# 5
# 60
# 30
# 6
# 13
# 8
# 4
# 10
# 12
# 34
# 13
# 19
# 35
# 12
# 17
# 12
# 4
# 25
# 4
# 20
# 12
# 2
# 33
# 8
# 10
# 10
# 41
# 6
# 5
# 2
# 3
# 31
# 30
# 25
# 4
# 14
# 8
# 6
# 6
# 4
# 17
# 6
# 18
# 12
# 18
# 5
# 9
# 3
# 19
# 28
# 11
# 9
# 19
# 15
# 5
# 27
# 57
# 12
# 26
# 33
# 32
# 22
# 23
# 31
# 16
# 5
# 34
# 11
# 8
# 18
# 8
# 5
# 4
# 11
# 4
# 9
# 22
# 6
# 10
# 54
# 50
# 47
# 56
# 14
# 44
# 5
# 8
# 6
# 48
# 9
# 4
# 7
# 6
# 9
# 4
# 11
# 11
# 14
# 9
# 38
# 7
# 4
# 3
# 7
# 30
# 3
# 19
# 20
# 6
# 11
# 6
# 9
# 5
# 6
# 11
# 16
# 17
# 2
# 8
# 8
# 9
# 14
# 3
# 15
# 4
# 3
# 7
# 14
# 10
# 23
# 5
# 7
# 4
# 12
# 27
# 13
# 19
# 22
# 8
# 5
# 7
# 16
# 18
# 24
# ...
